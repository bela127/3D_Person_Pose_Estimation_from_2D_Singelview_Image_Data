# %%
import sys
# !{sys.executable} -m pip uninstall -y ShAReD_Net
# Out:
# WARNING: The directory '/.cache/pip' or its parent directory is not owned or is not writable by the current user. The cache has been disabled. Check the permissions and owner of that directory. If executing pip with sudo, you may want sudo's -H flag.
# Found existing installation: ShAReD-Net 1.0
# Uninstalling ShAReD-Net-1.0:
#   Successfully uninstalled ShAReD-Net-1.0

# %%
import sys
# !{sys.executable} -m pip install ./src
# Out:
# WARNING: The directory '/.cache/pip' or its parent directory is not owned or is not writable by the current user. The cache has been disabled. Check the permissions and owner of that directory. If executing pip with sudo, you may want sudo's -H flag.
# Defaulting to user installation because normal site-packages is not writeable
# Processing ./src
# Building wheels for collected packages: ShAReD-Net
#   Building wheel for ShAReD-Net (setup.py) ... done
#   Created wheel for ShAReD-Net: filename=ShAReD_Net-1.0-py3-none-any.whl size=21801 sha256=6a3d51237305889894deb5c06692361c5a76bc0e801f8b6bed5d0def11058a87
#   Stored in directory: /tmp/pip-ephem-wheel-cache-8hluydn7/wheels/22/c3/70/c7c197844357b787f75a5309992d7aa6bb1d79ad298e7a9445
# Successfully built ShAReD-Net
# Installing collected packages: ShAReD-Net
#   Attempting uninstall: ShAReD-Net
#     Found existing installation: ShAReD-Net 1.0
#     Uninstalling ShAReD-Net-1.0:
#       Successfully uninstalled ShAReD-Net-1.0
# Successfully installed ShAReD-Net-1.0

# %%
import ShAReD_Net.training.run_train as train
train.main()
# Out:
# 2.2.0-dev20200305
# Init Model
# Tracing with Tensor("inputs:0", dtype=float32) Tensor("inputs_1:0", shape=(None, 15, 3), dtype=float32)
# Step: 1
# Step: 2
# Step: 3
# Step: 4
# Step: 5
# Step: 6
# Step: 7
# Step: 8
# Step: 9
# Step: 10
# Loss: 85630264
# Step: 11
# Step: 12
# Step: 13
# Step: 14
# Step: 15
# Step: 16
# Step: 17
# Step: 18
# Step: 19
# Step: 20
# Loss: 78218008
# Step: 21
# Step: 22
# Step: 23
# Step: 24
# Step: 25
# Step: 26
# Step: 27
# Step: 28
# Step: 29
# Step: 30
# Loss: 71343088
# Step: 31
# Step: 32
# Step: 33
# Step: 34
# Step: 35
# Step: 36
# Step: 37
# Step: 38
# Step: 39
# Step: 40
# Loss: 65010456
# Step: 41
# Step: 42
# Step: 43
# Step: 44
# Step: 45
# Step: 46
# Step: 47
# Step: 48
# Step: 49
# Step: 50
# Loss: 59181856
# Step: 51
# Step: 52
# Step: 53
# Step: 54
# Step: 55
# Step: 56
# Step: 57
# Step: 58
# Step: 59
# Step: 60
# Loss: 53791036
# Step: 61
# Step: 62
# Step: 63
# Step: 64
# Step: 65
# Step: 66
# Step: 67
# Step: 68
# Step: 69
# Step: 70
# Loss: 48770848
# Step: 71
# Step: 72
# Step: 73
# Step: 74
# Step: 75
# Step: 76
# Step: 77
# Step: 78
# Step: 79
# Step: 80
# Loss: 44092292
# Step: 81
# Step: 82
# Step: 83
# Step: 84
# Step: 85
# Step: 86
# Step: 87
# Step: 88
# Step: 89
# Step: 90
# Loss: 39749668
# Step: 91
# Step: 92
# Step: 93
# Step: 94
# Step: 95
# Step: 96
# Step: 97
# Step: 98
# Step: 99
# Step: 100
# Loss: 35744180
# Step: 101
# Step: 102
# Step: 103
# Step: 104
# Step: 105
# Step: 106
# Step: 107
# Step: 108
# Step: 109
# Step: 110
# Loss: 32068132
# Step: 111
# Step: 112
# Step: 113
# Step: 114
# Step: 115
# Step: 116
# Step: 117
# Step: 118
# Step: 119
# Step: 120
# Loss: 28706038
# Step: 121
# Step: 122
# Step: 123
# Step: 124
# Step: 125
# Step: 126
# Step: 127
# Step: 128
# Step: 129
# Step: 130
# Loss: 25641056
# Step: 131
# Step: 132
# Step: 133
# Step: 134
# Step: 135
# Step: 136
# Step: 137
# Step: 138
# Step: 139
# Step: 140
# Loss: 22855544
# Step: 141
# Step: 142
# Step: 143
# Step: 144
# Step: 145
# Step: 146
# Step: 147
# Step: 148
# Step: 149
# Step: 150
# Loss: 20330858
# Step: 151
# Step: 152
# Step: 153
# Step: 154
# Step: 155
# Step: 156
# Step: 157
# Step: 158
# Step: 159
# Step: 160
# Loss: 18048674
# Step: 161
# Step: 162
# Step: 163
# Step: 164
# Step: 165
# Step: 166
# Step: 167
# Step: 168
# Step: 169
# Step: 170
# Loss: 15991036
# Step: 171
# Step: 172
# Step: 173
# Step: 174
# Step: 175
# Step: 176
# Step: 177
# Step: 178
# Step: 179
# Step: 180
# Loss: 14139872
# Step: 181
# Step: 182
# Step: 183
# Step: 184
# Step: 185
# Step: 186
# Step: 187
# Step: 188
# Step: 189
# Step: 190
# Loss: 12477520
# Step: 191
# Step: 192
# Step: 193
# Step: 194
# Step: 195
# Step: 196
# Step: 197
# Step: 198
# Step: 199
# Step: 200
# Loss: 10987388
# Step: 201
# Step: 202
# Step: 203
# Step: 204
# Step: 205
# Step: 206
# Step: 207
# Step: 208
# Step: 209
# Step: 210
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-1-722d7f8fcd4f> in <module>
#       1 import ShAReD_Net.training.run_train as train
# ----> 2 train.main()
#
# ~.local/lib/python3.6/site-packages/ShAReD_Net/training/run_train.py in main()
#      30     step_callbacks["train_init"] = init_model
#      31
# ---> 32     train.train(400, get_train_model, dataset, dist_strat, batch_size = 16, step_callbacks = step_callbacks)
#      33
#      34 def finish_training(train_model, loss, step):
#
# ~.local/lib/python3.6/site-packages/ShAReD_Net/training/train.py in train(steps, get_train_model, dataset, dist_strat, batch_size, learning_rate, step_callbacks)
#      96                             step_callback(train_model, loss, step)
#      97
# ---> 98     train_loop(dist_dataset)
#      99
#     100 if __name__ == "__main__":
#
# ~.local/lib/python3.6/site-packages/ShAReD_Net/training/train.py in train_loop(dist_dataset)
#      94                     for callback_step, step_callback in step_callbacks.items():
#      95                         if isinstance(callback_step,int) and callback_step > 0 and step % callback_step == 0:
# ---> 96                             step_callback(train_model, loss, step)
#      97
#      98     train_loop(dist_dataset)
#
# ~.local/lib/python3.6/site-packages/ShAReD_Net/training/train.py in print_loss(train_model, loss, step)
#      36
#      37 def print_loss(train_model, loss, step):
# ---> 38     tf.print("Loss:", loss)
#      39
#      40 def show_plot(train_model, loss, step):
#
# ~usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/logging_ops.py in print_v2(*inputs, **kwargs)
#     316     tensors = []
#     317     tensor_free_structure = nest.map_structure(
# --> 318         lambda x: "" if tensor_util.is_tensor(x) else x, inputs)
#     319     tensor_free_template = " ".join(
#     320         pprint.pformat(x) for x in tensor_free_structure)
#
# ~usr/local/lib/python3.6/dist-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     616   return pack_sequence_as(
#     617       structure[0], [func(*x) for x in entries],
# --> 618       expand_composites=expand_composites)
#     619
#     620
#
# ~usr/local/lib/python3.6/dist-packages/tensorflow/python/util/nest.py in pack_sequence_as(structure, flat_sequence, expand_composites)
#     550     TypeError: `structure` is or contains a dict with non-sortable keys.
#     551   """
# --> 552   return _pack_sequence_as(structure, flat_sequence, expand_composites)
#     553
#     554
#
# ~usr/local/lib/python3.6/dist-packages/tensorflow/python/util/nest.py in _pack_sequence_as(structure, flat_sequence, expand_composites, sequence_fn)
#     504   try:
#     505     final_index, packed = _packed_nest_with_indices(structure, flat_sequence,
# --> 506                                                     0, is_seq, sequence_fn)
#     507     if final_index < len(flat_sequence):
#     508       raise IndexError
#
# ~usr/local/lib/python3.6/dist-packages/tensorflow/python/util/nest.py in _packed_nest_with_indices(structure, flat, index, is_seq, sequence_fn)
#     472       index = new_index
#     473     else:
# --> 474       packed.append(flat[index])
#     475       index += 1
#     476   return index, packed
#
# KeyboardInterrupt:

# %%
# !{sys.executable} -m pip freeze
# Out:
# WARNING: The directory '/.cache/pip' or its parent directory is not owned or is not writable by the current user. The cache has been disabled. Check the permissions and owner of that directory. If executing pip with sudo, you may want sudo's -H flag.
# absl-py==0.9.0
# asn1crypto==0.24.0
# astunparse==1.6.3
# attrs==19.3.0
# backcall==0.1.0
# bleach==3.1.1
# cachetools==4.0.0
# certifi==2019.11.28
# chardet==3.0.4
# cryptography==2.1.4
# cycler==0.10.0
# decorator==4.4.2
# defusedxml==0.6.0
# entrypoints==0.3
# enum34==1.1.9
# gast==0.3.3
# google-auth==1.11.2
# google-auth-oauthlib==0.4.1
# google-pasta==0.1.8
# grpcio==1.27.2
# h5py==2.10.0
# idna==2.6
# importlib-metadata==1.5.0
# ipykernel==5.1.1
# ipython==7.13.0
# ipython-genutils==0.2.0
# ipywidgets==7.5.1
# jedi==0.16.0
# Jinja2==2.11.1
# jsonschema==3.2.0
# jupyter==1.0.0
# jupyter-client==6.0.0
# jupyter-console==6.1.0
# jupyter-core==4.6.3
# jupyter-http-over-ws==0.0.7
# Keras-Preprocessing==1.1.0
# keyring==10.6.0
# keyrings.alt==3.0
# kiwisolver==1.1.0
# Markdown==3.2.1
# MarkupSafe==1.1.1
# matplotlib==3.2.0
# mistune==0.8.4
# nbconvert==5.6.1
# nbformat==4.4.0
# notebook==6.0.3
# numpy==1.18.1
# oauthlib==3.1.0
# opt-einsum==3.2.0
# pandocfilters==1.4.2
# parso==0.6.2
# pexpect==4.8.0
# pickleshare==0.7.5
# prometheus-client==0.7.1
# prompt-toolkit==3.0.3
# protobuf==3.11.3
# ptyprocess==0.6.0
# pyasn1==0.4.8
# pyasn1-modules==0.2.8
# pycrypto==2.6.1
# Pygments==2.5.2
# pygobject==3.26.1
# pyparsing==2.4.6
# pyrsistent==0.15.7
# python-apt==1.6.5+ubuntu0.2
# python-dateutil==2.8.1
# pyxdg==0.25
# pyzmq==19.0.0
# qtconsole==4.7.1
# QtPy==1.9.0
# requests==2.23.0
# requests-oauthlib==1.3.0
# rsa==4.0
# scipy==1.4.1
# SecretStorage==2.3.1
# Send2Trash==1.5.0
# ShAReD-Net==1.0
# six==1.14.0
# tb-nightly==2.2.0a20200305
# tensorboard-plugin-wit==1.6.0.post2
# termcolor==1.1.0
# terminado==0.8.3
# testpath==0.4.4
# tf-estimator-nightly==2.1.0.dev2020030501
# tf-nightly-gpu==2.2.0.dev20200305
# tornado==6.0.4
# traitlets==4.3.3
# urllib3==1.25.8
# wcwidth==0.1.8
# webencodings==0.5.1
# Werkzeug==1.0.0
# widgetsnbextension==3.5.1
# wrapt==1.12.0
# zipp==3.1.0
